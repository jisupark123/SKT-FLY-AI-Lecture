# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
# !conda update --force conda
# Out:
# WARNING: The --force flag will be removed in a future conda release.
#          See 'conda update --help' for details about the --force-reinstall
#          and --clobber flags.
#
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::jupyterlab_server==2.8.2=pyhd3eb1b0_0
#   - defaults/noarch::cookiecutter==1.7.2=pyhd3eb1b0_0
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_7
#   - defaults/noarch::python-lsp-black==1.0.0=pyhd3eb1b0_0
#   - defaults/noarch::nbclient==0.5.3=pyhd3eb1b0_0
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/osx-64::nbconvert==6.1.0=py39hecd8cb5_0
#   - defaults/osx-64::bkcharts==0.2=py39hecd8cb5_0
#   - defaults/noarch::nbclassic==0.2.6=pyhd3eb1b0_0
#   - defaults/osx-64::distributed==2021.10.0=py39hecd8cb5_0
#   - defaults/osx-64::notebook==6.4.5=py39hecd8cb5_0
#   - defaults/noarch::sphinx==4.2.0=pyhd3eb1b0_1
#   - defaults/noarch::numpydoc==1.1.0=pyhd3eb1b0_1
#   - defaults/osx-64::conda-package-handling==1.7.3=py39h9ed2024_1
#   - defaults/osx-64::astropy==4.3.1=py39hf9932de_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_2
#   - defaults/osx-64::anaconda==2021.11=py39_0
#   - defaults/noarch::jsonschema==3.2.0=pyhd3eb1b0_2
#   - defaults/osx-64::anaconda-client==1.9.0=py39hecd8cb5_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_0
#   - defaults/noarch::nltk==3.6.5=pyhd3eb1b0_0
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/osx-64::scikit-image==0.18.3=py39hae1ba45_0
#   - defaults/noarch::black==19.10b0=py_0
#   - defaults/noarch::nbformat==5.1.3=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab==3.2.1=pyhd3eb1b0_1
#   - defaults/osx-64::spyder==5.1.5=py39hecd8cb5_1
#   - defaults/noarch::soupsieve==2.2.1=pyhd3eb1b0_0
#   - defaults/osx-64::statsmodels==0.12.2=py39h9ed2024_0
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/osx-64::jupyter_server==1.4.1=py39hecd8cb5_0
#   - defaults/noarch::conda-token==0.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::conda==4.12.0=py39hecd8cb5_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/osx-64::bokeh==2.4.1=py39hecd8cb5_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/osx-64::conda-build==3.21.5=py39hecd8cb5_0
#   - defaults/osx-64::widgetsnbextension==3.5.1=py39hecd8cb5_0
#   - defaults/noarch::anaconda-project==0.10.1=pyhd3eb1b0_0
#   - defaults/osx-64::matplotlib==3.4.3=py39hecd8cb5_0
#   - defaults/osx-64::anaconda-navigator==2.1.1=py39_0
# failed with repodata from current_repodata.json, will retry with next repodata source.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::jupyterlab_server==2.8.2=pyhd3eb1b0_0
#   - defaults/noarch::cookiecutter==1.7.2=pyhd3eb1b0_0
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_7
#   - defaults/noarch::python-lsp-black==1.0.0=pyhd3eb1b0_0
#   - defaults/noarch::nbclient==0.5.3=pyhd3eb1b0_0
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/osx-64::nbconvert==6.1.0=py39hecd8cb5_0
#   - defaults/osx-64::bkcharts==0.2=py39hecd8cb5_0
#   - defaults/noarch::nbclassic==0.2.6=pyhd3eb1b0_0
#   - defaults/osx-64::distributed==2021.10.0=py39hecd8cb5_0
#   - defaults/osx-64::notebook==6.4.5=py39hecd8cb5_0
#   - defaults/noarch::sphinx==4.2.0=pyhd3eb1b0_1
#   - defaults/noarch::numpydoc==1.1.0=pyhd3eb1b0_1
#   - defaults/osx-64::conda-package-handling==1.7.3=py39h9ed2024_1
#   - defaults/osx-64::astropy==4.3.1=py39hf9932de_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_2
#   - defaults/osx-64::anaconda==2021.11=py39_0
#   - defaults/noarch::jsonschema==3.2.0=pyhd3eb1b0_2
#   - defaults/osx-64::anaconda-client==1.9.0=py39hecd8cb5_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_0
#   - defaults/noarch::nltk==3.6.5=pyhd3eb1b0_0
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/osx-64::scikit-image==0.18.3=py39hae1ba45_0
#   - defaults/noarch::black==19.10b0=py_0
#   - defaults/noarch::nbformat==5.1.3=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab==3.2.1=pyhd3eb1b0_1
#   - defaults/osx-64::spyder==5.1.5=py39hecd8cb5_1
#   - defaults/noarch::soupsieve==2.2.1=pyhd3eb1b0_0
#   - defaults/osx-64::statsmodels==0.12.2=py39h9ed2024_0
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/osx-64::jupyter_server==1.4.1=py39hecd8cb5_0
#   - defaults/noarch::conda-token==0.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::conda==4.12.0=py39hecd8cb5_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/osx-64::bokeh==2.4.1=py39hecd8cb5_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/osx-64::conda-build==3.21.5=py39hecd8cb5_0
#   - defaults/osx-64::widgetsnbextension==3.5.1=py39hecd8cb5_0
#   - defaults/noarch::anaconda-project==0.10.1=pyhd3eb1b0_0
#   - defaults/osx-64::matplotlib==3.4.3=py39hecd8cb5_0
#   - defaults/osx-64::anaconda-navigator==2.1.1=py39_0
# / ^C
# \

# %%
# !conda install tensorflow -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::jupyterlab_server==2.8.2=pyhd3eb1b0_0
#   - defaults/noarch::cookiecutter==1.7.2=pyhd3eb1b0_0
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_7
#   - defaults/noarch::python-lsp-black==1.0.0=pyhd3eb1b0_0
#   - defaults/noarch::nbclient==0.5.3=pyhd3eb1b0_0
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/osx-64::nbconvert==6.1.0=py39hecd8cb5_0
#   - defaults/osx-64::bkcharts==0.2=py39hecd8cb5_0
#   - defaults/noarch::nbclassic==0.2.6=pyhd3eb1b0_0
#   - defaults/osx-64::distributed==2021.10.0=py39hecd8cb5_0
#   - defaults/osx-64::notebook==6.4.5=py39hecd8cb5_0
#   - defaults/noarch::sphinx==4.2.0=pyhd3eb1b0_1
#   - defaults/noarch::numpydoc==1.1.0=pyhd3eb1b0_1
#   - defaults/osx-64::conda-package-handling==1.7.3=py39h9ed2024_1
#   - defaults/osx-64::astropy==4.3.1=py39hf9932de_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_2
#   - defaults/osx-64::anaconda==2021.11=py39_0
#   - defaults/noarch::jsonschema==3.2.0=pyhd3eb1b0_2
#   - defaults/osx-64::anaconda-client==1.9.0=py39hecd8cb5_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_0
#   - defaults/noarch::nltk==3.6.5=pyhd3eb1b0_0
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/osx-64::scikit-image==0.18.3=py39hae1ba45_0
#   - defaults/noarch::black==19.10b0=py_0
#   - defaults/noarch::nbformat==5.1.3=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab==3.2.1=pyhd3eb1b0_1
#   - defaults/osx-64::spyder==5.1.5=py39hecd8cb5_1
#   - defaults/noarch::soupsieve==2.2.1=pyhd3eb1b0_0
#   - defaults/osx-64::statsmodels==0.12.2=py39h9ed2024_0
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/osx-64::jupyter_server==1.4.1=py39hecd8cb5_0
#   - defaults/noarch::conda-token==0.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::conda==4.12.0=py39hecd8cb5_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/osx-64::bokeh==2.4.1=py39hecd8cb5_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/osx-64::conda-build==3.21.5=py39hecd8cb5_0
#   - defaults/osx-64::widgetsnbextension==3.5.1=py39hecd8cb5_0
#   - defaults/noarch::anaconda-project==0.10.1=pyhd3eb1b0_0
#   - defaults/osx-64::matplotlib==3.4.3=py39hecd8cb5_0
#   - defaults/osx-64::anaconda-navigator==2.1.1=py39_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::jupyterlab_server==2.8.2=pyhd3eb1b0_0
#   - defaults/noarch::cookiecutter==1.7.2=pyhd3eb1b0_0
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_7
#   - defaults/noarch::python-lsp-black==1.0.0=pyhd3eb1b0_0
#   - defaults/noarch::nbclient==0.5.3=pyhd3eb1b0_0
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/osx-64::nbconvert==6.1.0=py39hecd8cb5_0
#   - defaults/osx-64::bkcharts==0.2=py39hecd8cb5_0
#   - defaults/noarch::nbclassic==0.2.6=pyhd3eb1b0_0
#   - defaults/osx-64::distributed==2021.10.0=py39hecd8cb5_0
#   - defaults/osx-64::notebook==6.4.5=py39hecd8cb5_0
#   - defaults/noarch::sphinx==4.2.0=pyhd3eb1b0_1
#   - defaults/noarch::numpydoc==1.1.0=pyhd3eb1b0_1
#   - defaults/osx-64::conda-package-handling==1.7.3=py39h9ed2024_1
#   - defaults/osx-64::astropy==4.3.1=py39hf9932de_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_2
#   - defaults/osx-64::anaconda==2021.11=py39_0
#   - defaults/noarch::jsonschema==3.2.0=pyhd3eb1b0_2
#   - defaults/osx-64::anaconda-client==1.9.0=py39hecd8cb5_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_0
#   - defaults/noarch::nltk==3.6.5=pyhd3eb1b0_0
#   - defaults/noarch::flask==1.1.2=pyhd3eb1b0_0
#   - defaults/osx-64::scikit-image==0.18.3=py39hae1ba45_0
#   - defaults/noarch::black==19.10b0=py_0
#   - defaults/noarch::nbformat==5.1.3=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab==3.2.1=pyhd3eb1b0_1
#   - defaults/osx-64::spyder==5.1.5=py39hecd8cb5_1
#   - defaults/noarch::soupsieve==2.2.1=pyhd3eb1b0_0
#   - defaults/osx-64::statsmodels==0.12.2=py39h9ed2024_0
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/osx-64::jupyter_server==1.4.1=py39hecd8cb5_0
#   - defaults/noarch::conda-token==0.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::conda==4.12.0=py39hecd8cb5_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/osx-64::bokeh==2.4.1=py39hecd8cb5_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/osx-64::conda-build==3.21.5=py39hecd8cb5_0
#   - defaults/osx-64::widgetsnbextension==3.5.1=py39hecd8cb5_0
#   - defaults/noarch::anaconda-project==0.10.1=pyhd3eb1b0_0
#   - defaults/osx-64::matplotlib==3.4.3=py39hecd8cb5_0
#   - defaults/osx-64::anaconda-navigator==2.1.1=py39_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 23.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/my_home/opt/anaconda3
#
#   added / updated specs:
#     - tensorflow
#
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-2021.11-py39_0
#   _tflow_select      pkgs/main/osx-64::_tflow_select-2.2.0-eigen
#   abseil-cpp         pkgs/main/osx-64::abseil-cpp-20211102.0-he9d5cce_0
#   absl-py            pkgs/main/osx-64::absl-py-1.4.0-py39hecd8cb5_0
#   aiohttp            pkgs/main/osx-64::aiohttp-3.9.0-py39h6c40b1e_0
#   aiosignal          pkgs/main/noarch::aiosignal-1.2.0-pyhd3eb1b0_0
#   anyio              pkgs/main/osx-64::anyio-3.5.0-py39hecd8cb5_0
#   astunparse         pkgs/main/noarch::astunparse-1.6.3-py_0
#   async-timeout      pkgs/main/osx-64::async-timeout-4.0.3-py39hecd8cb5_0
#   attrs              pkgs/main/osx-64::attrs-23.1.0-py39hecd8cb5_0
#   beautifulsoup4     pkgs/main/osx-64::beautifulsoup4-4.12.2-py39hecd8cb5_0
#   blinker            pkgs/main/osx-64::blinker-1.6.2-py39hecd8cb5_0
#   cachetools         pkgs/main/noarch::cachetools-4.2.2-pyhd3eb1b0_0
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   click              pkgs/main/osx-64::click-8.1.7-py39hecd8cb5_0
#   colorama           pkgs/main/osx-64::colorama-0.4.6-py39hecd8cb5_0
#   exceptiongroup     pkgs/main/osx-64::exceptiongroup-1.0.4-py39hecd8cb5_0
#   filelock           pkgs/main/osx-64::filelock-3.13.1-py39hecd8cb5_0
#   flatbuffers        pkgs/main/osx-64::flatbuffers-2.0.0-h23ab428_0
#   frozenlist         pkgs/main/osx-64::frozenlist-1.4.0-py39h6c40b1e_0
#   gast               pkgs/main/noarch::gast-0.4.0-pyhd3eb1b0_0
#   google-auth        pkgs/main/noarch::google-auth-2.6.0-pyhd3eb1b0_0
#   google-auth-oauth~ pkgs/main/noarch::google-auth-oauthlib-0.4.4-pyhd3eb1b0_0
#   google-pasta       pkgs/main/noarch::google-pasta-0.2.0-pyhd3eb1b0_0
#   grpc-cpp           pkgs/main/osx-64::grpc-cpp-1.46.1-h067a048_0
#   grpcio             pkgs/main/osx-64::grpcio-1.42.0-py39ha29bfda_0
#   jinja2             pkgs/main/noarch::jinja2-2.11.3-pyhd3eb1b0_0
#   keras              pkgs/main/osx-64::keras-2.9.0-py39hecd8cb5_0
#   keras-preprocessi~ pkgs/main/noarch::keras-preprocessing-1.1.2-pyhd3eb1b0_0
#   libprotobuf        pkgs/main/osx-64::libprotobuf-3.20.1-h8346a28_0
#   markdown           pkgs/main/osx-64::markdown-3.4.1-py39hecd8cb5_0
#   markupsafe         pkgs/main/osx-64::markupsafe-1.1.1-py39h9ed2024_0
#   matplotlib-base    pkgs/main/osx-64::matplotlib-base-3.4.3-py39h0a11d32_0
#   multidict          pkgs/main/osx-64::multidict-6.0.4-py39h6c40b1e_0
#   oauthlib           pkgs/main/osx-64::oauthlib-3.2.2-py39hecd8cb5_0
#   opt_einsum         pkgs/main/noarch::opt_einsum-3.3.0-pyhd3eb1b0_1
#   pandas             pkgs/main/osx-64::pandas-1.4.4-py39he9d5cce_0
#   pip                pkgs/main/osx-64::pip-23.3.1-py39hecd8cb5_0
#   protobuf           pkgs/main/osx-64::protobuf-3.20.1-py39he9d5cce_0
#   pyasn1             pkgs/main/noarch::pyasn1-0.4.8-pyhd3eb1b0_0
#   pyasn1-modules     pkgs/main/noarch::pyasn1-modules-0.2.8-py_0
#   pytest             pkgs/main/osx-64::pytest-7.4.0-py39hecd8cb5_0
#   python-flatbuffers pkgs/main/noarch::python-flatbuffers-1.12-pyhd3eb1b0_0
#   re2                pkgs/main/osx-64::re2-2022.04.01-he9d5cce_0
#   regex              pkgs/main/osx-64::regex-2023.10.3-py39h6c40b1e_0
#   requests           pkgs/main/osx-64::requests-2.31.0-py39hecd8cb5_0
#   requests-oauthlib  pkgs/main/noarch::requests-oauthlib-1.3.0-py_0
#   rsa                pkgs/main/noarch::rsa-4.7.2-pyhd3eb1b0_1
#   tensorboard        pkgs/main/osx-64::tensorboard-2.9.0-py39hecd8cb5_0
#   tensorboard-data-~ pkgs/main/osx-64::tensorboard-data-server-0.6.1-py39h7242b5c_0
#   tensorboard-plugi~ pkgs/main/noarch::tensorboard-plugin-wit-1.6.0-py_0
#   tensorflow         pkgs/main/osx-64::tensorflow-2.9.1-eigen_py39h7123b6a_1
#   tensorflow-base    pkgs/main/osx-64::tensorflow-base-2.9.1-eigen_py39h36d2db2_1
#   tensorflow-estima~ pkgs/main/osx-64::tensorflow-estimator-2.9.0-py39hecd8cb5_0
#   termcolor          pkgs/main/osx-64::termcolor-2.1.0-py39hecd8cb5_0
#   tomli              pkgs/main/osx-64::tomli-2.0.1-py39hecd8cb5_0
#   tqdm               pkgs/main/osx-64::tqdm-4.65.0-py39h01d92e1_0
#   typing_extensions  pkgs/main/osx-64::typing_extensions-4.7.1-py39hecd8cb5_0
#   yarl               pkgs/main/osx-64::yarl-1.9.3-py39h6c40b1e_0
#
# The following packages will be UPDATED:
#
#   c-ares                                  1.17.1-h9ed2024_0 --> 1.19.1-h6c40b1e_0
#   ca-certificates                     2021.10.26-hecd8cb5_2 --> 2023.12.12-hecd8cb5_0
#   certifi                          2021.10.8-py39hecd8cb5_0 --> 2023.11.17-py39hecd8cb5_0
#   curl                                    7.78.0-h7bc2e8c_0 --> 7.87.0-h6c40b1e_0
#   jpeg                                        9d-h9ed2024_0 --> 9e-h6c40b1e_1
#   libcurl                                 7.78.0-hb8e4fae_0 --> 7.87.0-ha585b31_0
#   libnghttp2                              1.41.0-h7580e61_2 --> 1.46.0-ha29bfda_0
#   libssh2                                  1.9.0-ha12b0ac_1 --> 1.10.0-hdb2fb19_2
#   llvm-openmp                             12.0.0-h0dcd299_1 --> 14.0.6-h0dcd299_0
#   openssl                                 1.1.1l-h9ed2024_0 --> 1.1.1w-hca72f7f_0
#   scipy                                1.7.1-py39h88652d9_2 --> 1.7.3-py39h8c7af03_0
#   snappy                                   1.1.8-hb1e8313_0 --> 1.1.9-he9d5cce_0
#   sqlite                                  3.36.0-hce871da_0 --> 3.40.1-h880c91c_0
#   zlib                                    1.2.11-h1de35cc_3 --> 1.2.13-h4dc903c_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2021.11-py39_0 --> custom-py39_2
#   wheel                                 0.37.0-pyhd3eb1b0_1 --> 0.35.1-pyhd3eb1b0_0
#
#
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'requests' is a dependency of conda and cannot be removed from
# conda's operating environment.

# %%
iris = sns.load_dataset('iris')
iris
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gj/67qmbl1124q796vn1dgpljqr0000gp/T/ipykernel_47596/13026444.py in <module>
# ----> 1 iris = sns.load_dataset('iris')
#       2 iris
#
# NameError: name 'sns' is not defined

# %%
from sklearn.model_selection import train_test_split

X = iris.drop('iris','species', axis=1)
y = iris['species']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gj/67qmbl1124q796vn1dgpljqr0000gp/T/ipykernel_47596/3779414578.py in <module>
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X = iris.drop('iris','species', axis=1)
#       4 y = iris['species']
#       5
#
# NameError: name 'iris' is not defined
