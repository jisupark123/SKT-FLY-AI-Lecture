# %%
import pandas as pd
import numpy as np

# %%
data = [1,2,3]
ser = pd.Series(data, index=['a','b','c'])
ser
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ser.loc['a':'c']
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ser[[True, False, True]] # True에 해당하는 값만 출력
# Out:
# a    1
# c    3
# dtype: int64

# %%
ser != 2 # 조건식 -> boolean 값으로 출력
# Out:
# a     True
# b    False
# c     True
# dtype: bool

# %%
ser[ser != 2] # 조건식을 넣어서 True에 해당하는 값만 출력
# Out:
# a    1
# c    3
# dtype: int64

# %% [markdown]
# ## DataFrame

# %%
data = [[1,10,100], [2,20,200], [3,30,300]]
df = pd.DataFrame(data, index=['r1','r2','r3'], columns=['c1','c2','c3'])
df
# Out:
#     c1  c2   c3
# r1   1  10  100
# r2   2  20  200
# r3   3  30  300

# %%
df.loc[['r1','r3'], ['c2','c3']] # r1, r3 행의 c2, c3 열의 값 출력
# Out:
#     c2   c3
# r1  10  100
# r3  30  300

# %% [markdown]
# ## CSV 파일 불러오기

# %%
df = pd.read_csv('../data/anime.csv')
df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
# 인덱스로 할 열을 번호로 지정
df = pd.read_csv('../data/anime.csv', index_col=0)
df.head()
# Out:
#                                       name  \
# anime_id
# 32281                       Kimi no Na wa.
# 5114      Fullmetal Alchemist: Brotherhood
# 28977                             Gintama°
# 9253                           Steins;Gate
# 9969                         Gintama&#039;
#
#                                                       genre   type episodes  \
# anime_id
# 32281                  Drama, Romance, School, Supernatural  Movie        1
# 5114      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 28977     Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 9253                                       Sci-Fi, Thriller     TV       24
# 9969      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
#
#           rating  members
# anime_id
# 32281       9.37   200630
# 5114        9.26   793665
# 28977       9.25   114262
# 9253        9.17   673572
# 9969        9.16   151266

# %%
# 인덱스로 할 열을 이름으로 지정
df = pd.read_csv('../data/anime.csv', index_col='anime_id')
df.head()
# Out:
#                                       name  \
# anime_id
# 32281                       Kimi no Na wa.
# 5114      Fullmetal Alchemist: Brotherhood
# 28977                             Gintama°
# 9253                           Steins;Gate
# 9969                         Gintama&#039;
#
#                                                       genre   type episodes  \
# anime_id
# 32281                  Drama, Romance, School, Supernatural  Movie        1
# 5114      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 28977     Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 9253                                       Sci-Fi, Thriller     TV       24
# 9969      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
#
#           rating  members
# anime_id
# 32281       9.37   200630
# 5114        9.26   793665
# 28977       9.25   114262
# 9253        9.17   673572
# 9969        9.16   151266

# %%
# 지정한 열을 지정한 형으로 불러오기
df = pd.read_csv('../data/anime.csv', dtype={'members': float})
df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#     members
# 0  200630.0
# 1  793665.0
# 2  114262.0
# 3  673572.0
# 4  151266.0

# %%
# datetime 형으로 불러오기
pd.read_csv('../data/anime_stock_price.csv', parse_dates=['Date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            522 non-null    datetime64[ns]
#  1   TOEI ANIMATION  522 non-null    float64
#  2   IG Port         522 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 12.4 KB

# %% [markdown]
# ## Excel 파일 불러오기

# %%
import openpyxl

df = pd.read_excel('../data/anime.xlsx')
df.head()
# Out:
#    anime_id                                               name  \
# 0     32281                                     Kimi no Na wa.
# 1     15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 2     28851                                     Koe no Katachi
# 3       199                      Sen to Chihiro no Kamikakushi
# 4     12355                       Ookami Kodomo no Ame to Yuki
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Comedy, Historical, Parody, Samurai, S...  Movie        1    9.10
# 2                             Drama, School, Shounen  Movie        1    9.05
# 3                     Adventure, Drama, Supernatural  Movie        1    8.93
# 4                             Fantasy, Slice of Life  Movie        1    8.84
#
#    members
# 0   200630
# 1    72534
# 2   102733
# 3   466254
# 4   226193

# %% [markdown]
# ## SQL 파일 불러오기

# %%
# !pip install pandasql
# Out:
# Collecting pandasql
#   Using cached pandasql-0.7.3-py3-none-any.whl
# Requirement already satisfied: numpy in /Users/my_home/opt/anaconda3/lib/python3.9/site-packages (from pandasql) (1.20.3)
# Requirement already satisfied: pandas in /Users/my_home/opt/anaconda3/lib/python3.9/site-packages (from pandasql) (2.0.3)
# Requirement already satisfied: sqlalchemy in /Users/my_home/opt/anaconda3/lib/python3.9/site-packages (from pandasql) (1.4.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/my_home/opt/anaconda3/lib/python3.9/site-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/my_home/opt/anaconda3/lib/python3.9/site-packages (from pandas->pandasql) (2021.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/my_home/opt/anaconda3/lib/python3.9/site-packages (from pandas->pandasql) (2023.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/my_home/opt/anaconda3/lib/python3.9/site-packages (from sqlalchemy->pandasql) (1.1.1)
# Requirement already satisfied: six>=1.5 in /Users/my_home/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.16.0)
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
from pandasql import sqldf
dfsql = lambda q:sqldf(q, globals()) # globals() : 전역변수를 딕셔너리 형태로 출력
result = dfsql('select name, rating from df where rating > 9 order by rating desc')
result.head()
# Out:
#                                                 name  rating
# 0            Taka no Tsume 8: Yoshida-kun no X-Files   10.00
# 1                                   Mogura no Motoro    9.50
# 2                                     Kimi no Na wa.    9.37
# 3                                       Kahei no Umi    9.33
# 4  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...    9.10

# %%
# 결과를 json 형태로 출력
result.to_json('../data/result.json', orient='table')

# %% [markdown]
# ## HTML

# %%
url = 'https://docs.python.org/3/py-modindex.html'
table = pd.read_html(url)

# 첫 번째 DataFrame에서 빈 열과 결손값을 제외
table[0].loc[:,1:].dropna().head(10)
# Out:
#              1                                                  2
# 2   __future__                       Future statement definitions
# 3     __main__  The environment where top-level code is run. C...
# 4      _thread                           Low-level threading API.
# 5     _tkinter  A binary module that contains the low-level in...
# 8          abc    Abstract base classes according to :pep:`3119`.
# 9         aifc  Deprecated:  Read and write audio files in AIF...
# 10    argparse  Command-line option and argument parsing library.
# 11       array  Space efficient arrays of uniformly typed nume...
# 12         ast     Abstract Syntax Tree classes and manipulation.
# 13     asyncio                                  Asynchronous I/O.

# %% [markdown]
# ## 그 밖의 메소드들..

# %%
df.where(df['rating'] < 9.2).head()
# Out:
#    anime_id                                               name  \
# 0       NaN                                                NaN
# 1   15335.0  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 2   28851.0                                     Koe no Katachi
# 3     199.0                      Sen to Chihiro no Kamikakushi
# 4   12355.0                       Ookami Kodomo no Ame to Yuki
#
#                                                genre   type episodes  rating  \
# 0                                                NaN    NaN      NaN     NaN
# 1  Action, Comedy, Historical, Parody, Samurai, S...  Movie        1    9.10
# 2                             Drama, School, Shounen  Movie        1    9.05
# 3                     Adventure, Drama, Supernatural  Movie        1    8.93
# 4                             Fantasy, Slice of Life  Movie        1    8.84
#
#     members
# 0       NaN
# 1   72534.0
# 2  102733.0
# 3  466254.0
# 4  226193.0

# %%
# rating 순으로 정렬
df.sort_values('rating', ascending=False).head()
# Out:
#       anime_id                                               name  \
# 2143     33662            Taka no Tsume 8: Yoshida-kun no X-Files
# 1894     23005                                   Mogura no Motoro
# 0        32281                                     Kimi no Na wa.
# 1753     33607                                       Kahei no Umi
# 1        15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
#
#                                                   genre   type episodes  \
# 2143                                     Comedy, Parody  Movie        1
# 1894                                      Slice of Life  Movie        1
# 0                  Drama, Romance, School, Supernatural  Movie        1
# 1753                                         Historical  Movie        1
# 1     Action, Comedy, Historical, Parody, Samurai, S...  Movie        1
#
#       rating  members
# 2143   10.00       13
# 1894    9.50       62
# 0       9.37   200630
# 1753    9.33       44
# 1       9.10    72534
